# %%
from pathlib import Path
from nb_utils import unzip, DATA_DIR, RESULTS_DIR
import pandas as pd
import os

# %%
# Extracted results, load to frame and delete the large CSV
unzip(DATA_DIR / 'sfconvertbot_pr_metadata.csv.zip', DATA_DIR)
df = pd.read_csv(Path('../../data/sfconvertbot_pr_metadata.csv'))
os.remove(DATA_DIR / 'sfconvertbot_pr_metadata.csv')
# add a date column
df['date'] = df['time'].str.split('T').str[0]
df['date'] = df['date'].str.split(' ').str[0]
# ensure date column is a datetime object
df['date'] = pd.to_datetime(df['date'])
# filter in place, keep only commits before Aug 31 2024 (including)
df = df[df['date'] <= pd.Timestamp(2024, 8, 31)]


# series for collecting dataset stats, columns = metric / value
stats = pd.Series()
stats.loc['Number of collected PRs'] = len(df)

# remove rows with missing values
df = df.dropna()
stats.loc['Number of PRs after removing missing values'] = len(df)

# remove rows with invalid JSONs
df = df[df['discussion_metadata'].str.startswith('{')]
stats.loc['Number of PRs after removing invalid JSONs'] = len(df)



# exclude PRs made on spaces/safetensors/convert
df = df[~df['pr_url'].str.contains('/spaces/safetensors/convert/discussions')]
stats.loc['Number of PRs after filtering by URL'] = len(df)

# show some stats
stats.loc['Number of repositories'] = df['model_id'].nunique()
stats.loc['Average number of PRs per repository'] = df['model_id'].value_counts().mean()
stats.loc['First commit time'] = df['time'].min()
stats.loc['Last commit time'] = df['time'].max()

stats
# Out:
# Number of collected PRs                                         43650.0
# Number of PRs after removing missing values                     43598.0
# Number of PRs after removing invalid JSONs                      43598.0
# Number of PRs after filtering by URL                            43596.0
# Number of repositories                                          35094.0
# Average number of PRs per repository                           1.242264
# First commit time                              2022-11-07T13:00:55.000Z
# Last commit time                               2024-08-31T23:41:59.000Z
# dtype: object

# %%
from tqdm import tqdm
import json

def label_status(row: pd.Series) -> str:
    # check if the PR has conflicts
    if row['conflicts']:
        return f"{row['status']} (has conflicts)"
    return row['status']

# Extract status changes from discussion metadata
for index, row in tqdm(df.iterrows(), total=len(df)):
    # add a column to track status changes
    status_changes = []
    discussion = json.loads(row['discussion_metadata'])['discussion']
    created_at = pd.to_datetime(discussion['createdAt'])
    author = discussion['author']['name']
    
    first_status_change_date = None
    df.at[index, 'was_status_changed_by_hf_staff'] = False
    for event in discussion['events']:
        event_type = event['type']
        
        if event_type == 'status-change':
            status_changes.append(event['data']['status'])
            # this means author has been deleted
            if 'author' not in event:
                event['author'] = {'name': 'UNKNOWN (likely a deleted account)', 'isHf':False}
            
            # convert to datetime
            if not first_status_change_date and event['author']['name'].lower() != 'sfconvertbot':
                first_status_change_date = pd.to_datetime(event['createdAt'])
                if event['author']['isHf']:
                    df.at[index, 'was_status_changed_by_hf_staff'] = True

    df.at[index, 'status_changes'] = ";".join(status_changes)

    # add a column to track files with conflicts
    df.at[index, 'conflicts'] = ""
    header = json.loads(row['header_metadata'])
    df.at[index, 'status'] = header['discussion']['status']
    # check if there are conflicting files
    conflicting_files = header['discussion'].get('filesWithConflicts', [])
    df.at[index, 'conflicts'] = ";".join(conflicting_files)
    # time to first response
    df.at[
        index, 'time_to_first_response'] = first_status_change_date - created_at if first_status_change_date else None
    # adjust the status
    df.at[index, 'status'] = label_status(df.loc[index])
    # Add a year column
    df['year'] = df['date'].dt.year

stats
# Out:
# 100%|██████████| 43596/43596 [00:40<00:00, 1089.75it/s]
# Number of collected PRs                                         43650.0
# Number of PRs after removing missing values                     43598.0
# Number of PRs after removing invalid JSONs                      43598.0
# Number of PRs after filtering by URL                            43596.0
# Number of repositories                                          35094.0
# Average number of PRs per repository                           1.242264
# First commit time                              2022-11-07T13:00:55.000Z
# Last commit time                               2024-08-31T23:41:59.000Z
# dtype: object

# %%
df
# Out:
#                                                   pr_url  \
# 2146   https://huggingface.co/Emmaruyi/CompetitionSty...
# 2147   https://huggingface.co/Delta-Vector/Holland-4B...
# 2148   https://huggingface.co/vespa-engine/col-minilm...
# 2149   https://huggingface.co/Abhaykoul/Abhayjr/discu...
# 2150   https://huggingface.co/robotics-diffusion-tran...
# ...                                                  ...
# 46315  https://huggingface.co/pchatz/palobert-base-gr...
# 46316  https://huggingface.co/Merry/pythia-160m-dedup...
# 46321  https://huggingface.co/babylm/t5-base-strict/d...
# 46322  https://huggingface.co/zhaozh/autotrain-pubmed...
# 46323  https://huggingface.co/zhaozh/autotrain-trans-...
#
#                                      discussion_metadata  \
# 2146   {"apiBaseUrl":"/api/models/Emmaruyi/Competitio...
# 2147   {"apiBaseUrl":"/api/models/Delta-Vector/Hollan...
# 2148   {"apiBaseUrl":"/api/models/vespa-engine/col-mi...
# 2149   {"apiBaseUrl":"/api/models/Abhaykoul/Abhayjr",...
# 2150   {"apiBaseUrl":"/api/models/robotics-diffusion-...
# ...                                                  ...
# 46315  {"apiBaseUrl":"/api/models/pchatz/palobert-bas...
# 46316  {"apiBaseUrl":"/api/models/Crataco/Pythia-160M...
# 46321  {"apiBaseUrl":"/api/models/babylm/t5-base-stri...
# 46322  {"apiBaseUrl":"/api/models/sindri101/autotrain...
# 46323  {"apiBaseUrl":"/api/models/sindri101/autotrain...
#
#                                          header_metadata  \
# 2146   {"discussion":{"_id":"66d3aa474b87a685cc25d69a...
# 2147   {"discussion":{"_id":"66d33f63b4396d43c3bab8a5...
# 2148   {"discussion":{"_id":"66d1c3704c596f785214538c...
# 2149   {"discussion":{"_id":"66d03d85378dfa1ea4a6565b...
# 2150   {"discussion":{"_id":"66d01d22d2480a2555be07d4...
# ...                                                  ...
# 46315  {"discussion":{"_id":"642c682aac7e48a03a0999c2...
# 46316  {"discussion":{"_id":"642c71f9c811cd1de5bacd0d...
# 46321  {"discussion":{"_id":"642cbf013bf67e40142189c6...
# 46322  {"discussion":{"_id":"642d0c4f9efab84585efbea6...
# 46323  {"discussion":{"_id":"642d0c6dc811cd1de5bea1f1...
#
#                                               model_id  \
# 2146   Emmaruyi/CompetitionStyle-ArchitectureGenerator
# 2147                        Delta-Vector/Holland-4B-V1
# 2148                           vespa-engine/col-minilm
# 2149                                 Abhaykoul/Abhayjr
# 2150             robotics-diffusion-transformer/rdt-1b
# ...                                                ...
# 46315          pchatz/palobert-base-greek-social-media
# 46316                    Merry/pythia-160m-deduped-aid
# 46321                            babylm/t5-base-strict
# 46322   zhaozh/autotrain-pubmed-medft-tiny-46854115566
# 46323        zhaozh/autotrain-trans-pubmed-46884115623
#
#                            time       date was_status_changed_by_hf_staff  \
# 2146   2024-08-31T23:41:59.000Z 2024-08-31                          False
# 2147   2024-08-31T16:05:55.000Z 2024-08-31                          False
# 2148   2024-08-30T13:04:48.000Z 2024-08-30                          False
# 2149   2024-08-29T09:21:09.000Z 2024-08-29                          False
# 2150   2024-08-29T07:02:58.000Z 2024-08-29                          False
# ...                         ...        ...                            ...
# 46315  2023-04-04T18:10:50.000Z 2023-04-04                          False
# 46316  2023-04-04T18:52:41.000Z 2023-04-04                          False
# 46321  2023-04-05T00:21:21.000Z 2023-04-05                          False
# 46322  2023-04-05T05:51:11.000Z 2023-04-05                          False
# 46323  2023-04-05T05:51:41.000Z 2023-04-05                          False
#
#       status_changes conflicts  status time_to_first_response  year
# 2146          merged            merged        0 days 00:02:15  2024
# 2147          merged            merged        0 days 00:02:20  2024
# 2148                              open                    NaT  2024
# 2149          merged            merged        0 days 00:00:30  2024
# 2150                              open                    NaT  2024
# ...              ...       ...     ...                    ...   ...
# 46315                             open                    NaT  2023
# 46316         merged            merged        0 days 02:57:19  2023
# 46321                             open                    NaT  2023
# 46322                             open                    NaT  2023
# 46323                             open                    NaT  2023
#
# [43596 rows x 12 columns]

# %%
from nb_utils import read_repositories_evolution

# model files per repository and the elapsed days between the commit and safetensors' release date
repos = read_repositories_evolution()
repos['year'] = repos['date'].dt.year

# find the last commit hash per repository per year
df_last_hash = repos.sort_values('date').drop_duplicates(['repo_url', 'year'], keep='last')
df_last_hash = df_last_hash[['repo_url', 'year', 'commit_hash', 'date']]

# filter df such that if  only keeps the rows in df if the commit hash is the last commit hash in the repository URL
repos = repos.merge(df_last_hash, on=['repo_url', 'year', 'date', 'commit_hash'], how='inner')
"Min date", repos['date'].min(),"Max date",  repos['date'].max()
# Out:
# ('Min date',
#  Timestamp('2019-09-23 15:48:20'),
#  'Max date',
#  Timestamp('2024-08-26 04:05:14'))

# %%
repos
# Out:
#                            repo_url                               commit_hash  \
# 0     rinna/japanese-gpt-neox-small  f33d44540298e143079f34c35b21eebe4f3dce89
# 1     rinna/japanese-gpt-neox-small  f33d44540298e143079f34c35b21eebe4f3dce89
# 2     rinna/japanese-gpt-neox-small  f33d44540298e143079f34c35b21eebe4f3dce89
# 3     rinna/japanese-gpt-neox-small  f3cdc9a0868ac3d6dbd8f7431f719dc07c5114e9
# 4     rinna/japanese-gpt-neox-small  f3cdc9a0868ac3d6dbd8f7431f719dc07c5114e9
# ...                             ...                                       ...
# 7545          albert/albert-base-v1  66b3f3c279cf3a1df6d8df1cffa60d4d026ea396
# 7546          albert/albert-base-v1  7b2207b0995b9618ed866befd087bee3673f022d
# 7547          albert/albert-base-v1  7b2207b0995b9618ed866befd087bee3673f022d
# 7548          albert/albert-base-v1  7b2207b0995b9618ed866befd087bee3673f022d
# 7549          albert/albert-base-v1  7b2207b0995b9618ed866befd087bee3673f022d
#
#               model_file_path serialization_format  \
# 0           model.safetensors          safetensors
# 1           pytorch_model.bin           torch.save
# 2                spiece.model                 ONNX
# 3           pytorch_model.bin           torch.save
# 4                spiece.model                 ONNX
# ...                       ...                  ...
# 7545  with-prefix-tf_model.h5              h5/hdf5
# 7546        pytorch_model.bin           torch.save
# 7547             spiece.model                 ONNX
# 7548              tf_model.h5              h5/hdf5
# 7549  with-prefix-tf_model.h5              h5/hdf5
#
#                                                 message          author  \
# 0     Adding `safetensors` variant of this model (#2...     Tianyu Zhao
# 1     Adding `safetensors` variant of this model (#2...     Tianyu Zhao
# 2     Adding `safetensors` variant of this model (#2...     Tianyu Zhao
# 3                                           init commit     Tianyu Zhao
# 4                                           init commit     Tianyu Zhao
# ...                                                 ...             ...
# 7545  Adding `safetensors` variant of this model (#1...  Sylvain Gugger
# 7546                                 Update tf_model.h5          system
# 7547                                 Update tf_model.h5          system
# 7548                                 Update tf_model.h5          system
# 7549                                 Update tf_model.h5          system
#
#                     date  is_in_commit change_status  elapsed_days  year
# 0    2023-08-04 06:46:32          True             +           315  2023
# 1    2023-08-04 06:46:32         False           NaN           315  2023
# 2    2023-08-04 06:46:32         False           NaN           315  2023
# 3    2022-08-31 02:01:42          True             +           -23  2022
# 4    2022-08-31 02:01:42          True             +           -23  2022
# ...                  ...           ...           ...           ...   ...
# 7545 2023-04-06 09:42:57         False           NaN           195  2023
# 7546 2020-06-22 11:29:35         False           NaN          -823  2020
# 7547 2020-06-22 11:29:35         False           NaN          -823  2020
# 7548 2020-06-22 11:29:35          True             +          -823  2020
# 7549 2020-06-22 11:29:35         False           NaN          -823  2020
#
# [7550 rows x 11 columns]

# %%
repos_torch_save = repos[repos['serialization_format'] == 'torch.save']
repos_torch_save
# Out:
#                                        repo_url  \
# 1                 rinna/japanese-gpt-neox-small
# 3                 rinna/japanese-gpt-neox-small
# 5     Intel/roberta-base-squad2-int8-static-inc
# 6     Intel/roberta-base-squad2-int8-static-inc
# 7                              saphvis/ngpx2022
# ...                                         ...
# 7531                      albert/albert-base-v2
# 7535                      albert/albert-base-v2
# 7539                      albert/albert-base-v2
# 7542                      albert/albert-base-v1
# 7546                      albert/albert-base-v1
#
#                                    commit_hash    model_file_path  \
# 1     f33d44540298e143079f34c35b21eebe4f3dce89  pytorch_model.bin
# 3     f3cdc9a0868ac3d6dbd8f7431f719dc07c5114e9  pytorch_model.bin
# 5     79caea4b54eec88d1a75f641ecce4446aa8fd2a9  pytorch_model.bin
# 6     79caea4b54eec88d1a75f641ecce4446aa8fd2a9  training_args.bin
# 7     d5011c5daf903087aa8d424c878cc82640611d1d        ngpx2022.pt
# ...                                        ...                ...
# 7531  c3fcc1d2675a05929ea687d4ffbb537d1aa9c57a  pytorch_model.bin
# 7535  44ec114441af838d5133509b2bf7ed774c6b93c1  pytorch_model.bin
# 7539  ada8cde1d4486a2de1a5a1a242d43251074bf415  pytorch_model.bin
# 7542  66b3f3c279cf3a1df6d8df1cffa60d4d026ea396  pytorch_model.bin
# 7546  7b2207b0995b9618ed866befd087bee3673f022d  pytorch_model.bin
#
#      serialization_format                                            message  \
# 1              torch.save  Adding `safetensors` variant of this model (#2...
# 3              torch.save                                        init commit
# 5              torch.save                                 upload int8 model.
# 6              torch.save                                 upload int8 model.
# 7              torch.save                             ngpx2022 400000 upload
# ...                   ...                                                ...
# 7531           torch.save  Adding `safetensors` variant of this model (#2...
# 7535           torch.save                                 Update tf_model.h5
# 7539           torch.save                           Update pytorch_model.bin
# 7542           torch.save  Adding `safetensors` variant of this model (#1...
# 7546           torch.save                                 Update tf_model.h5
#
#                  author                date  is_in_commit change_status  \
# 1           Tianyu Zhao 2023-08-04 06:46:32         False           NaN
# 3           Tianyu Zhao 2022-08-31 02:01:42          True             +
# 5            Lv, Kaokao 2022-08-30 05:25:59          True             +
# 6            Lv, Kaokao 2022-08-30 05:25:59          True             +
# 7     ocular degenerate 2022-08-29 21:26:46          True             +
# ...                 ...                 ...           ...           ...
# 7531     Sylvain Gugger 2023-04-06 09:39:39         False           NaN
# 7535             system 2020-06-22 11:32:37         False           NaN
# 7539             system 2019-11-06 11:24:17          True             +
# 7542     Sylvain Gugger 2023-04-06 09:42:57         False           NaN
# 7546             system 2020-06-22 11:29:35         False           NaN
#
#       elapsed_days  year
# 1              315  2023
# 3              -23  2022
# 5              -24  2022
# 6              -24  2022
# 7              -25  2022
# ...            ...   ...
# 7531           195  2023
# 7535          -823  2020
# 7539         -1052  2019
# 7542           195  2023
# 7546          -823  2020
#
# [5843 rows x 11 columns]

# %%
df_open_status = df[df['status'] == 'open']
df_open_status
# Out:
#                                                   pr_url  \
# 2148   https://huggingface.co/vespa-engine/col-minilm...
# 2150   https://huggingface.co/robotics-diffusion-tran...
# 2151   https://huggingface.co/Kwai-Kolors/Kolors-IP-A...
# 2153   https://huggingface.co/cerspense/zeroscope_v2_...
# 2154   https://huggingface.co/cvssp/audioldm-l-full/d...
# ...                                                  ...
# 46309  https://huggingface.co/babylm/roberta-base-str...
# 46315  https://huggingface.co/pchatz/palobert-base-gr...
# 46321  https://huggingface.co/babylm/t5-base-strict/d...
# 46322  https://huggingface.co/zhaozh/autotrain-pubmed...
# 46323  https://huggingface.co/zhaozh/autotrain-trans-...
#
#                                      discussion_metadata  \
# 2148   {"apiBaseUrl":"/api/models/vespa-engine/col-mi...
# 2150   {"apiBaseUrl":"/api/models/robotics-diffusion-...
# 2151   {"apiBaseUrl":"/api/models/Kwai-Kolors/Kolors-...
# 2153   {"apiBaseUrl":"/api/models/cerspense/zeroscope...
# 2154   {"apiBaseUrl":"/api/models/cvssp/audioldm-l-fu...
# ...                                                  ...
# 46309  {"apiBaseUrl":"/api/models/babylm/roberta-base...
# 46315  {"apiBaseUrl":"/api/models/pchatz/palobert-bas...
# 46321  {"apiBaseUrl":"/api/models/babylm/t5-base-stri...
# 46322  {"apiBaseUrl":"/api/models/sindri101/autotrain...
# 46323  {"apiBaseUrl":"/api/models/sindri101/autotrain...
#
#                                          header_metadata  \
# 2148   {"discussion":{"_id":"66d1c3704c596f785214538c...
# 2150   {"discussion":{"_id":"66d01d22d2480a2555be07d4...
# 2151   {"discussion":{"_id":"66cfd824aab5a6fbf824503c...
# 2153   {"discussion":{"_id":"66cef3496116c7f53e8327c0...
# 2154   {"discussion":{"_id":"66ced702103ac47986f07ad4...
# ...                                                  ...
# 46309  {"discussion":{"_id":"642c25fafe98081a6fdd65f3...
# 46315  {"discussion":{"_id":"642c682aac7e48a03a0999c2...
# 46321  {"discussion":{"_id":"642cbf013bf67e40142189c6...
# 46322  {"discussion":{"_id":"642d0c4f9efab84585efbea6...
# 46323  {"discussion":{"_id":"642d0c6dc811cd1de5bea1f1...
#
#                                              model_id  \
# 2148                          vespa-engine/col-minilm
# 2150            robotics-diffusion-transformer/rdt-1b
# 2151               Kwai-Kolors/Kolors-IP-Adapter-Plus
# 2153                      cerspense/zeroscope_v2_576w
# 2154                            cvssp/audioldm-l-full
# ...                                               ...
# 46309                      babylm/roberta-base-strict
# 46315         pchatz/palobert-base-greek-social-media
# 46321                           babylm/t5-base-strict
# 46322  zhaozh/autotrain-pubmed-medft-tiny-46854115566
# 46323       zhaozh/autotrain-trans-pubmed-46884115623
#
#                            time       date was_status_changed_by_hf_staff  \
# 2148   2024-08-30T13:04:48.000Z 2024-08-30                          False
# 2150   2024-08-29T07:02:58.000Z 2024-08-29                          False
# 2151   2024-08-29T02:08:36.000Z 2024-08-29                          False
# 2153   2024-08-28T09:52:09.000Z 2024-08-28                          False
# 2154   2024-08-28T07:51:30.000Z 2024-08-28                          False
# ...                         ...        ...                            ...
# 46309  2023-04-04T13:28:26.000Z 2023-04-04                          False
# 46315  2023-04-04T18:10:50.000Z 2023-04-04                          False
# 46321  2023-04-05T00:21:21.000Z 2023-04-05                          False
# 46322  2023-04-05T05:51:11.000Z 2023-04-05                          False
# 46323  2023-04-05T05:51:41.000Z 2023-04-05                          False
#
#       status_changes conflicts status time_to_first_response  year
# 2148                             open                    NaT  2024
# 2150                             open                    NaT  2024
# 2151                             open                    NaT  2024
# 2153                             open                    NaT  2024
# 2154                             open                    NaT  2024
# ...              ...       ...    ...                    ...   ...
# 46309                            open                    NaT  2023
# 46315                            open                    NaT  2023
# 46321                            open                    NaT  2023
# 46322                            open                    NaT  2023
# 46323                            open                    NaT  2023
#
# [36422 rows x 12 columns]

# %%
matching_instances = pd.merge(
    df_open_status,
    repos_torch_save,
    left_on='model_id',
    right_on='repo_url',
    how='inner'
)

# Get the count of matching instances
matching_count = len(matching_instances)

# Print the count
print(f"Number of matching instances: {matching_count}")
# Out:
# Number of matching instances: 300

# %%
matching_instances_no_dups = matching_instances.drop_duplicates()

# Get the count of unique matching instances
matching_count_no_dups = len(matching_instances_no_dups)

# Print the count
print(f"Number of unique matching instances: {matching_count_no_dups}")
# Out:
# Number of unique matching instances: 300
